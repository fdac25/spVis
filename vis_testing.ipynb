# %%
import pandas as pd
import glob
import matplotlib.pyplot as plt

# %%
json_path = "Spotify_Extended_Streaming_History/Streaming_History_Audio_2021_9.json"
df = pd.read_json(json_path)

print(df.head())

artist_count = df["master_metadata_album_artist_name"].value_counts()
#print(artist_count)
album_count = df["master_metadata_album_album_name"].value_counts()
#print(album_count)
# Out:
#                      ts                      platform  ms_played conn_country  \
# 0  2021-07-13T00:41:32Z         iOS 14.6 (iPhone12,1)     312973           US
# 1  2021-07-13T00:47:43Z         iOS 14.6 (iPhone12,1)     370506           US
# 2  2021-07-13T00:51:12Z         iOS 14.6 (iPhone12,1)     209093           US
# 3  2021-07-13T01:32:49Z  Windows 10 (10.0.19042; x64)     268333           US
# 4  2021-07-13T01:39:00Z  Windows 10 (10.0.19042; x64)     370506           US
#
#            ip_addr master_metadata_track_name  \
# 0  184.174.150.253             Neptune Estate
# 1  184.174.150.253                  Honestly?
# 2  184.174.150.253       Sweep Me Off My Feet
# 3  184.174.150.253                Never Meant
# 4  184.174.150.253                  Honestly?
#
#   master_metadata_album_artist_name master_metadata_album_album_name  \
# 0                        King Krule          6 Feet Beneath The Moon
# 1                 American Football                American Football
# ...

# %%
json_path_kale = "Spotify_Extended_Streaming_History/Streaming_History_Audio_*.json"
dfs = []

for file in glob.glob(json_path_kale):
  data = pd.read_json(file)
  dfs.append(data)

combined_df = pd.concat(dfs, ignore_index=True)


print(combined_df.head())
num_rows = combined_df.shape[0]
print(num_rows)

'''artist_count = combined_df["master_metadata_album_artist_name"].value_counts()
print(artist_count)
album_count = combined_df["master_metadata_album_album_name"].value_counts()
print(album_count)'''
# Out:
#                      ts platform  ms_played conn_country          ip_addr  \
# 0  2023-05-20T02:45:34Z      ios     109309           US  174.212.104.164
# 1  2023-05-20T02:47:56Z      ios     141479           US  174.212.104.164
# 2  2023-05-20T02:50:58Z      ios     181721           US  174.212.104.164
# 3  2023-05-20T02:54:27Z      ios     208693           US  174.212.104.164
# 4  2023-05-20T02:54:44Z      ios      14585           US  174.212.104.164
#
#   master_metadata_track_name master_metadata_album_artist_name  \
# 0                       Name                         spill tab
# 1               Aqrxvst (29)                          Pretty V
# 2                         52                          Pretty V
# 3                        A/B                              Pond
# 4                 I Am Bored                   The Microphones
#
#   master_metadata_album_album_name                     spotify_track_uri  \
# ...

# %%
num_rows = combined_df.shape[0]
print(num_rows)

artist_count_2 = combined_df['master_metadata_album_artist_name'].value_counts()
print(artist_count_2.head())
artist_count_top_5 = artist_count_2.head()
artist_count_top_15 = artist_count_2.head(15)

plt.bar(artist_count_top_5.index, artist_count_top_5.values, color=['red', 'blue', 'orange', 'purple', 'green'])
plt.xlabel('Artist')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

plt.bar(artist_count_top_15.index, artist_count_top_15.values, color=['red', 'blue', 'orange', 'purple', 'green'])
plt.xlabel('Artist')
plt.ylabel('Count')
plt.xticks(rotation=45)
#plt.tight_layout()
plt.show()

album_count_2 = combined_df['master_metadata_album_album_name'].value_counts()
album_count_top_5 = album_count_2.head()

plt.bar(album_count_top_5.index, album_count_top_5.values, color=['red', 'blue', 'orange', 'purple', 'green'])
plt.xlabel('Album')
plt.ylabel('Count')
plt.xticks(rotation=45)
#plt.tight_layout()
plt.show()

cometh_count = artist_count_2['Kanye West']
print(f"# of streams for Kanye West: {cometh_count}")
# Out:
# 349608
# master_metadata_album_artist_name
# MIKE                  8797
# Tyler, The Creator    7273
# Earl Sweatshirt       7203
# Lil Peep              6693
# King Krule            6668
# Name: count, dtype: int64
# # of streams for Kanye West: 3374
